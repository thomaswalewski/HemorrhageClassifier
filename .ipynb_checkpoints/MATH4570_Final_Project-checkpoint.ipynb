# %% [markdown]
# # Brain Hemorrhage Identification
#
# #### David Pogrebitskiy, Scott Biggs, Thomas Walewski, Jared Garfinkel, Karenna Ng, Sarah Baker
# #### MATH 4570, Fall 2022

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from skimage.measure import block_reduce

# %% [markdown]
# ## Data importing and cleaning

# %%
# import results files
epidural = pd.read_csv('label_files/Results_Epidural Hemorrhage Detection_2020-11-16_21.31.26.148.csv')
intraparenchymal = pd.read_csv('label_files/Results_Intraparenchymal Hemorrhage Detection_2020-11-16_21.39.31.268.csv')
multiple = pd.read_csv('label_files/Results_Multiple Hemorrhage Detection_2020-11-16_21.36.24.018.csv')
subarachnoid = pd.read_csv('label_files/Results_Subarachnoid Hemorrhage Detection_2020-11-16_21.36.18.668.csv')
subdural = pd.read_csv('label_files/Results_Subdural Hemorrhage Detection_2020-11-16_21.37.19.745.csv')

# %%
def clean_labels(raw_data, hem_type):
    
    # choose best position label
    for i in range(len(raw_data)):
        row = raw_data.loc[i]
        if pd.isna(raw_data.loc[i,'Correct Label']):
            label = raw_data.loc[i,'Majority Label']
        else:
            label = raw_data.loc[i,'Correct Label']
        raw_data.loc[i,'Label'] = label
    
    # give overall type label
    raw_data['hem_type'] = hem_type
    
    # drop rows with no labels
    cleaned = raw_data[raw_data['Label'].str.contains('x')]
    return cleaned

# %%
# clean and assign labels
epi = clean_labels(epidural, "epidural")
intra = clean_labels(intraparenchymal, "intraparenchymal")
multi = clean_labels(multiple, "multiple")
suba = clean_labels(subarachnoid, "subarachnoid")
subd = clean_labels(subdural, "subdural")

# %%
# combine all label files
types_list = [epi, intra, multi, suba, subd]
a_labels = pd.concat(types_list)

# drop flagged rows
a_labels = a_labels.loc[a_labels['Labeling State'] != 'Flagged']
a_labels.reset_index(inplace=True)

#all_labels.to_csv('all_labels.csv')
a_labels
# Out:
#       index  Case ID            Origin  \
# 0         0  1196514  ID_004c4b319.jpg
# 1         1  1196682  ID_0237b835f.jpg
# 2         2  1196477  ID_02e2d273d.jpg
# 3         3  1196612  ID_02f37ce84.jpg
# 4         4  1196612  ID_02f37ce84.jpg
# ...     ...      ...               ...
# 4642    738  1198392  ID_ff1e93267.jpg
# 4643    739  1198392  ID_ff1e93267.jpg
# 4644    740  1198414  ID_ff2f3dbb7.jpg
# 4645    741  1198334  ID_04ab5246e.jpg
# 4646    743  1198467  ID_2ef211ac4.jpg
#
#                                              URL Labeling State  \
# 0     https://go.centaurlabs.com/problem/1196514        Labeled
# 1     https://go.centaurlabs.com/problem/1196682          Ready
# 2     https://go.centaurlabs.com/problem/1196477        Labeled
# 3     https://go.centaurlabs.com/problem/1196612          Ready
# 4     https://go.centaurlabs.com/problem/1196612          Ready
# ...                                          ...            ...
# 4642  https://go.centaurlabs.com/problem/1198392        Labeled
# 4643  https://go.centaurlabs.com/problem/1198392        Labeled
# 4644  https://go.centaurlabs.com/problem/1198414        Labeled
# 4645  https://go.centaurlabs.com/problem/1198334        Labeled
# 4646  https://go.centaurlabs.com/problem/1198467        Labeled
#
#                                              All Labels  Total Reads  \
# 0     ['[{"x": 0.40818718, "y": 0.8623607}, {"x": 0....         19.0
# 1     ['[{"x": 0.62959146, "y": 0.720186}, {"x": 0.6...         51.0
# 2     ['[{"x": 0.35205495, "y": 0.34680602}, {"x": 0...         22.0
# 3     ['[{"x": 0.3680166, "y": 0.48387372}, {"x": 0....         51.0
# 4     ['[{"x": 0.3680166, "y": 0.48387372}, {"x": 0....         51.0
# ...                                                 ...          ...
# 4642  ['[{"x": 0.25159726, "y": 0.24648584}, {"x": 0...         19.0
# 4643  ['[{"x": 0.25159726, "y": 0.24648584}, {"x": 0...         19.0
# 4644  ['[{"x": 0.70854944, "y": 0.6837957}, {"x": 0....         14.0
# 4645  ['[{"x": 0.56073856, "y": 0.6705539}, {"x": 0....         13.0
# 4646  ['[{"x": 0.31171963, "y": 0.61459357}, {"x": 0...         11.0
#
#       Total Qualified Reads  \
# 0                       5.0
# 1                      28.0
# 2                       6.0
# 3                      29.0
# 4                      29.0
# ...                     ...
# 4642                    5.0
# 4643                    5.0
# 4644                    6.0
# 4645                    6.0
# 4646                    5.0
#
#                                          Majority Label  Number of ROIs  \
# 0     [{"x": 0.537109375, "y": 0.89453125}, {"x": 0....             1.0
# 1     [{"x": 0.654296875, "y": 0.724609375}, {"x": 0...             1.0
# 2     [{"x": 0.46484375, "y": 0.357421875}, {"x": 0....             1.0
# 3     [{"x": 0.431640625, "y": 0.607421875}, {"x": 0...             2.0
# 4     [{"x": 0.353515625, "y": 0.59765625}, {"x": 0....             2.0
# ...                                                 ...             ...
# 4642  [{"x": 0.68359375, "y": 0.42578125}, {"x": 0.6...             3.0
# 4643  [{"x": 0.630859375, "y": 0.24609375}, {"x": 0....             3.0
# 4644  [{"x": 0.70703125, "y": 0.67578125}, {"x": 0.7...             1.0
# 4645                                                 []             0.0
# 4646                                                 []             0.0
#
#                                           Correct Label  Difficulty  \
# 0     [[{'x': 0.537109375, 'y': 0.89453125}, {'x': 0...        0.00
# 1                                                   NaN         NaN
# 2     [[{'x': 0.46484375, 'y': 0.357421875}, {'x': 0...        0.06
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 4642  [[{'x': 0.685546875, 'y': 0.43359375}, {'x': 0...        0.48
# 4643  [[{'x': 0.685546875, 'y': 0.43359375}, {'x': 0...        0.48
# 4644  [[{'x': 0.70703125, 'y': 0.67578125}, {'x': 0....        0.15
# 4645  [[{'x': 0.560546875, 'y': 0.669921875}, {'x': ...        0.33
# 4646  [[{'x': 0.302734375, 'y': 0.62109375}, {'x': 0...        0.00
#
#       Agreement Comments  Internal Notes  \
# 0      0.968851      NaN             NaN
# 1      0.063519      NaN             NaN
# 2      0.710300      NaN             NaN
# 3      0.264134      NaN             NaN
# 4      0.264134      NaN             NaN
# ...         ...      ...             ...
# 4642   0.607623      NaN             NaN
# 4643   0.607623      NaN             NaN
# 4644   0.153092      NaN             NaN
# 4645   0.833333      NaN             NaN
# 4646   0.800000      NaN             NaN
#
#                                                   Label  hem_type
# 0     [[{'x': 0.537109375, 'y': 0.89453125}, {'x': 0...  epidural
# 1     [{"x": 0.654296875, "y": 0.724609375}, {"x": 0...  epidural
# 2     [[{'x': 0.46484375, 'y': 0.357421875}, {'x': 0...  epidural
# 3     [{"x": 0.431640625, "y": 0.607421875}, {"x": 0...  epidural
# 4     [{"x": 0.353515625, "y": 0.59765625}, {"x": 0....  epidural
# ...                                                 ...       ...
# 4642  [[{'x': 0.685546875, 'y': 0.43359375}, {'x': 0...  subdural
# 4643  [[{'x': 0.685546875, 'y': 0.43359375}, {'x': 0...  subdural
# 4644  [[{'x': 0.70703125, 'y': 0.67578125}, {'x': 0....  subdural
# 4645  [[{'x': 0.560546875, 'y': 0.669921875}, {'x': ...  subdural
# 4646  [[{'x': 0.302734375, 'y': 0.62109375}, {'x': 0...  subdural
#
# [4647 rows x 17 columns]

# %%
# categories and counts
a_labels.loc[:,'hem_type'].value_counts()
# Out:
# intraparenchymal    1262
# multiple            1047
# subarachnoid        1028
# subdural             734
# epidural             576
# Name: hem_type, dtype: int64

# %%
# add normal images
norm = pd.read_csv('normal_labels/test35.csv')
norm = norm.T.reset_index().rename(columns={'index':'Origin'})
norm['hem_type'] = 'normal'
norm['Origin'] = norm['Origin'].apply(lambda x: x.replace(' ', ''))

# %%
# Empty array to fill with images
all_labels = pd.concat([a_labels, norm]).reset_index()
data = np.zeros([(len(all_labels)), (512*512)])

# Select image type
image_type = 'brain_bone_window' # this window was found to have the highest accuracy in a test logistic regression
# Open files and load into array
for n, file_name in enumerate(all_labels.Origin):
    folder = all_labels.loc[n,'hem_type']
    file_dir = f'{folder}/{image_type}/{file_name}'
    try:
        data[n,:] = np.mean(matplotlib.image.imread(file_dir),axis=2).reshape(-1)
    except:
        continue
# Now we can use the file name to read the data

# %%
# length of full dataset used for training and testing
len(all_labels)
# Out:
# 7313

# %%
# example CT scan
plt.imshow(data[15].reshape(512,512))

# %% [markdown]
# ## SoftMax (Logistic Regression)
#
# Run on raw image data (full size)

# %%
y = all_labels.loc[:,'hem_type']

from sklearn.model_selection import train_test_split

# split data into train and test
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.1, random_state=0)
print(y_train.shape, y_test.shape)
# Out:
# (6581,) (732,)

# %%
# average of scans of each category
fig, (ax0, ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=4, figsize=(16, 6))

ax0.imshow(X_train[y_train == 'epidural'].mean(0).reshape(512,512), cmap='Greys')
ax0.set_title('epidural')
ax1.imshow(X_train[y_train == 'intraparenchymal'].mean(0).reshape(512,512), cmap='Greys')
ax1.set_title('intraparenchymal')
ax2.imshow(X_train[y_train == 'subarachnoid'].mean(0).reshape(512,512), cmap='Greys')
ax2.set_title('subarachnoid')
ax3.imshow(X_train[y_train == 'normal'].mean(0).reshape(512,512), cmap='Greys')
ax3.set_title('normal')
# Out:
# Text(0.5, 1.0, 'normal')

# %%
from sklearn.linear_model import LogisticRegression

# fit logistic regression to flattened/label-processed data
clf = LogisticRegression()
clf.fit(X_train, y_train)

# print score on the test data
print("Logistic Regression Score: %.4f"%clf.score(X_test,y_test))
# Out:
# /Users/dpogrebitskiy/opt/anaconda3/envs/ds/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Score: 0.5301

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(clf, X_test, y_test)
# Out:
# /Users/dpogrebitskiy/opt/anaconda3/envs/ds/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Neural Network 1
#
# Run on raw image data (full size)

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# build nn model with 3 layers
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(512*512,)))
model.add(keras.layers.Dense(1000, activation='relu'))
model.add(keras.layers.Dense(6, activation='softmax'))

# %%
# print layer diagram
from keras.utils.vis_utils import plot_model
keras.utils.plot_model(model, "nn_v1.png", show_shapes=True)

# %%
from keras.utils import np_utils

# make dummies for labels
Y_train = pd.get_dummies(y_train).values
Y_test = pd.get_dummies(y_test).values

# compile model and fit/validate on raw image data
model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

history = model.fit(X_train, Y_train, epochs=20, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 206/206 [==============================] - 158s 739ms/step - loss: 3895.3745 - accuracy: 0.3085 - val_loss: 450.2683 - val_accuracy: 0.3333
# Epoch 2/20
# 206/206 [==============================] - 146s 703ms/step - loss: 220.5432 - accuracy: 0.3369 - val_loss: 44.7051 - val_accuracy: 0.1516
# Epoch 3/20
# 206/206 [==============================] - 145s 705ms/step - loss: 6.2643 - accuracy: 0.3466 - val_loss: 6.3224 - val_accuracy: 0.3784
# Epoch 4/20
# 206/206 [==============================] - 144s 700ms/step - loss: 2.2357 - accuracy: 0.3636 - val_loss: 1.9591 - val_accuracy: 0.3784
# Epoch 5/20
# 206/206 [==============================] - 144s 700ms/step - loss: 1.7488 - accuracy: 0.3635 - val_loss: 6.5991 - val_accuracy: 0.3784
# Epoch 6/20
# 206/206 [==============================] - 144s 701ms/step - loss: 7.2480 - accuracy: 0.3620 - val_loss: 1.6727 - val_accuracy: 0.3798
# Epoch 7/20
# 206/206 [==============================] - 143s 696ms/step - loss: 2.2399 - accuracy: 0.3635 - val_loss: 2.9900 - val_accuracy: 0.3784
# Epoch 8/20
# 206/206 [==============================] - 144s 700ms/step - loss: 1.7011 - accuracy: 0.3636 - val_loss: 3.3522 - val_accuracy: 0.3784
# Epoch 9/20
# 206/206 [==============================] - 144s 699ms/step - loss: 1.8459 - accuracy: 0.3636 - val_loss: 1.6566 - val_accuracy: 0.3798
# Epoch 10/20
# 206/206 [==============================] - 144s 700ms/step - loss: 1.7078 - accuracy: 0.3635 - val_loss: 1.6559 - val_accuracy: 0.3798
# Epoch 11/20
# 206/206 [==============================] - 144s 698ms/step - loss: 1.6583 - accuracy: 0.3635 - val_loss: 1.6575 - val_accuracy: 0.3784
# Epoch 12/20
# 206/206 [==============================] - 144s 699ms/step - loss: 1.6544 - accuracy: 0.3636 - val_loss: 1.6583 - val_accuracy: 0.3784
# Epoch 13/20
# 206/206 [==============================] - 145s 703ms/step - loss: 1.6542 - accuracy: 0.3636 - val_loss: 1.6577 - val_accuracy: 0.3784
# Epoch 14/20
# 206/206 [==============================] - 143s 694ms/step - loss: 1.6543 - accuracy: 0.3636 - val_loss: 1.6587 - val_accuracy: 0.3784
# Epoch 15/20
# 206/206 [==============================] - 144s 697ms/step - loss: 1.6543 - accuracy: 0.3636 - val_loss: 1.6589 - val_accuracy: 0.3784
# Epoch 16/20
# 206/206 [==============================] - 150s 730ms/step - loss: 1.6541 - accuracy: 0.3636 - val_loss: 1.6582 - val_accuracy: 0.3784
# Epoch 17/20
# 206/206 [==============================] - 144s 701ms/step - loss: 1.6541 - accuracy: 0.3636 - val_loss: 1.6592 - val_accuracy: 0.3784
# Epoch 18/20
# 206/206 [==============================] - 144s 697ms/step - loss: 1.6542 - accuracy: 0.3636 - val_loss: 1.6592 - val_accuracy: 0.3784
# Epoch 19/20
# 206/206 [==============================] - 144s 698ms/step - loss: 1.6542 - accuracy: 0.3636 - val_loss: 1.6594 - val_accuracy: 0.3784
# Epoch 20/20
# 206/206 [==============================] - 144s 698ms/step - loss: 1.6542 - accuracy: 0.3636 - val_loss: 1.6594 - val_accuracy: 0.3784

# %% [markdown]
# ## Neural Network 2
#
# Run on downscaled images

# %%
# downscale images
DS =  16

N_train = y_train.shape[0]
y_train = np.array(y_train)

im_size = int(262144/DS)

data1 = np.zeros([len(all_labels), im_size])

for i, row in enumerate(data):
    data1[i,:] = row[::DS] # take every 16th pixel in the x-direction

# %%
plt.imshow(data1[1500].reshape(128,128))

# %%
# split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data1, y, test_size=0.2, random_state=0)
print(y_train.shape, y_test.shape)
# Out:
# (5850,) (1463,)

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# redefining model
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(128*128,)))
model.add(keras.layers.Dense(1000, activation='relu'))
model.add(keras.layers.Dense(6, activation='softmax'))

# print layer diagram
keras.utils.plot_model(model, "nn_v2.png", show_shapes=True)

# %%
from keras.utils import np_utils

# make dummies for labels
Y_train = pd.get_dummies(y_train).values
Y_test = pd.get_dummies(y_test).values

# compile model and fit/validate on downscaled image data
model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

history = model.fit(X_train, Y_train, epochs=20, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 183/183 [==============================] - 11s 57ms/step - loss: 356.6736 - accuracy: 0.2978 - val_loss: 41.0615 - val_accuracy: 0.2755
# Epoch 2/20
# 183/183 [==============================] - 9s 49ms/step - loss: 27.6424 - accuracy: 0.3643 - val_loss: 21.1356 - val_accuracy: 0.2953
# Epoch 3/20
# 183/183 [==============================] - 9s 52ms/step - loss: 10.8391 - accuracy: 0.3668 - val_loss: 1.8008 - val_accuracy: 0.1408
# Epoch 4/20
# 183/183 [==============================] - 9s 50ms/step - loss: 2.3778 - accuracy: 0.3508 - val_loss: 4.9003 - val_accuracy: 0.3807
# Epoch 5/20
# 183/183 [==============================] - 10s 56ms/step - loss: 2.5139 - accuracy: 0.3617 - val_loss: 2.2733 - val_accuracy: 0.3835
# Epoch 6/20
# 183/183 [==============================] - 10s 53ms/step - loss: 1.8303 - accuracy: 0.3646 - val_loss: 1.6684 - val_accuracy: 0.3869
# Epoch 7/20
# 183/183 [==============================] - 10s 54ms/step - loss: 1.6652 - accuracy: 0.3632 - val_loss: 1.8018 - val_accuracy: 0.3835
# Epoch 8/20
# 183/183 [==============================] - 10s 54ms/step - loss: 1.6950 - accuracy: 0.3627 - val_loss: 1.7112 - val_accuracy: 0.3869
# Epoch 9/20
# 183/183 [==============================] - 10s 55ms/step - loss: 1.6664 - accuracy: 0.3639 - val_loss: 1.6443 - val_accuracy: 0.3855
# Epoch 10/20
# 183/183 [==============================] - 10s 55ms/step - loss: 1.6344 - accuracy: 0.3646 - val_loss: 1.7516 - val_accuracy: 0.3841
# Epoch 11/20
# 183/183 [==============================] - 9s 52ms/step - loss: 1.6409 - accuracy: 0.3644 - val_loss: 1.7255 - val_accuracy: 0.3759
# Epoch 12/20
# 183/183 [==============================] - 9s 51ms/step - loss: 1.6330 - accuracy: 0.3632 - val_loss: 1.6328 - val_accuracy: 0.3848
# Epoch 13/20
# 183/183 [==============================] - 9s 51ms/step - loss: 1.6330 - accuracy: 0.3615 - val_loss: 1.6499 - val_accuracy: 0.3828
# Epoch 14/20
# 183/183 [==============================] - 10s 56ms/step - loss: 1.6317 - accuracy: 0.3627 - val_loss: 1.6303 - val_accuracy: 0.3835
# Epoch 15/20
# 183/183 [==============================] - 11s 59ms/step - loss: 1.6252 - accuracy: 0.3595 - val_loss: 1.6368 - val_accuracy: 0.3841
# Epoch 16/20
# 183/183 [==============================] - 11s 60ms/step - loss: 1.6337 - accuracy: 0.3624 - val_loss: 1.6432 - val_accuracy: 0.3841
# Epoch 17/20
# 183/183 [==============================] - 10s 52ms/step - loss: 1.6211 - accuracy: 0.3624 - val_loss: 1.6432 - val_accuracy: 0.3841
# Epoch 18/20
# 183/183 [==============================] - 10s 53ms/step - loss: 1.6367 - accuracy: 0.3624 - val_loss: 1.6320 - val_accuracy: 0.3841
# Epoch 19/20
# 183/183 [==============================] - 9s 52ms/step - loss: 1.6341 - accuracy: 0.3624 - val_loss: 1.6511 - val_accuracy: 0.3835
# Epoch 20/20
# 183/183 [==============================] - 10s 55ms/step - loss: 1.6506 - accuracy: 0.3621 - val_loss: 1.6429 - val_accuracy: 0.3841

# %% [markdown]
# ## Convolutional Neural Network 1
#
# Run on downscaled data

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# define model
model = Sequential()
model.add(Conv2D(32, (7,7),
                 padding='valid',
                 input_shape=(128,128,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, (3,3),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=6, activation='softmax'))

# complile model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# print layer diagram
keras.utils.plot_model(model, "cnn_v1.png", show_shapes=True)

# %%
import os

# early stopping
run_index = 1 # increment this at every run
run_logdir = os.path.join(os.curdir, "convolution_logs", "run_{:03d}".format(run_index))

early_stopping_cb = keras.callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=10,     # how many epochs to wait before stopping
)
checkpoint_cb = keras.callbacks.ModelCheckpoint("cnn.h5", save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

# fit and validate using downscaled image data with early stopping
history = model.fit(X_train,
                    Y_train,
                    epochs=1000,
                    batch_size=128,
                    verbose=1,
                    validation_data=(X_test, Y_test),
                    callbacks=[checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/1000
# 46/46 [==============================] - 32s 681ms/step - loss: 8.8127 - accuracy: 0.3055 - val_loss: 1.5938 - val_accuracy: 0.3896
# Epoch 2/1000
# 46/46 [==============================] - 31s 672ms/step - loss: 1.6144 - accuracy: 0.3685 - val_loss: 1.5751 - val_accuracy: 0.3923
# Epoch 3/1000
# 46/46 [==============================] - 41s 900ms/step - loss: 1.5490 - accuracy: 0.3826 - val_loss: 1.4970 - val_accuracy: 0.4012
# Epoch 4/1000
# 46/46 [==============================] - 31s 684ms/step - loss: 1.4929 - accuracy: 0.3959 - val_loss: 1.4908 - val_accuracy: 0.4231
# Epoch 5/1000
# 46/46 [==============================] - 31s 674ms/step - loss: 1.4329 - accuracy: 0.4202 - val_loss: 1.4514 - val_accuracy: 0.4457
# Epoch 6/1000
# 46/46 [==============================] - 31s 679ms/step - loss: 1.4050 - accuracy: 0.4299 - val_loss: 1.4170 - val_accuracy: 0.4552
# Epoch 7/1000
# 46/46 [==============================] - 31s 675ms/step - loss: 1.3417 - accuracy: 0.4684 - val_loss: 1.3651 - val_accuracy: 0.4737
# Epoch 8/1000
# 46/46 [==============================] - 31s 677ms/step - loss: 1.2664 - accuracy: 0.4897 - val_loss: 1.3444 - val_accuracy: 0.4928
# Epoch 9/1000
# 46/46 [==============================] - 31s 677ms/step - loss: 1.2232 - accuracy: 0.5176 - val_loss: 1.2949 - val_accuracy: 0.5338
# Epoch 10/1000
# 46/46 [==============================] - 31s 679ms/step - loss: 1.1490 - accuracy: 0.5462 - val_loss: 1.2561 - val_accuracy: 0.5475
# Epoch 11/1000
# 46/46 [==============================] - 31s 680ms/step - loss: 1.0928 - accuracy: 0.5761 - val_loss: 1.2473 - val_accuracy: 0.5537
# Epoch 12/1000
# 46/46 [==============================] - 31s 677ms/step - loss: 1.0322 - accuracy: 0.5928 - val_loss: 1.2476 - val_accuracy: 0.5632
# Epoch 13/1000
# 46/46 [==============================] - 26s 575ms/step - loss: 0.9900 - accuracy: 0.6038 - val_loss: 1.1863 - val_accuracy: 0.5919
# Epoch 14/1000
# 46/46 [==============================] - 27s 578ms/step - loss: 0.9523 - accuracy: 0.6246 - val_loss: 1.1806 - val_accuracy: 0.6104
# Epoch 15/1000
# 46/46 [==============================] - 27s 587ms/step - loss: 0.9115 - accuracy: 0.6456 - val_loss: 1.1657 - val_accuracy: 0.6104
# Epoch 16/1000
# 46/46 [==============================] - 27s 577ms/step - loss: 0.8682 - accuracy: 0.6614 - val_loss: 1.1310 - val_accuracy: 0.6241
# Epoch 17/1000
# 46/46 [==============================] - 30s 660ms/step - loss: 0.8228 - accuracy: 0.6749 - val_loss: 1.1152 - val_accuracy: 0.6384
# Epoch 18/1000
# 46/46 [==============================] - 32s 697ms/step - loss: 0.7903 - accuracy: 0.6892 - val_loss: 1.1014 - val_accuracy: 0.6384
# Epoch 19/1000
# 46/46 [==============================] - 31s 680ms/step - loss: 0.7472 - accuracy: 0.7036 - val_loss: 1.1017 - val_accuracy: 0.6411
# Epoch 20/1000
# 46/46 [==============================] - 32s 707ms/step - loss: 0.7273 - accuracy: 0.7138 - val_loss: 1.1146 - val_accuracy: 0.6617
# Epoch 21/1000
# 46/46 [==============================] - 32s 693ms/step - loss: 0.7093 - accuracy: 0.7176 - val_loss: 1.1358 - val_accuracy: 0.6678
# Epoch 22/1000
# 46/46 [==============================] - 29s 620ms/step - loss: 0.6854 - accuracy: 0.7280 - val_loss: 1.0894 - val_accuracy: 0.6767
# Epoch 23/1000
# 46/46 [==============================] - 31s 677ms/step - loss: 0.6577 - accuracy: 0.7388 - val_loss: 1.1163 - val_accuracy: 0.6637
# Epoch 24/1000
# 46/46 [==============================] - 39s 843ms/step - loss: 0.6125 - accuracy: 0.7568 - val_loss: 1.1239 - val_accuracy: 0.6808
# Epoch 25/1000
# 46/46 [==============================] - 37s 808ms/step - loss: 0.6166 - accuracy: 0.7562 - val_loss: 1.1105 - val_accuracy: 0.6774
# Epoch 26/1000
# 46/46 [==============================] - 33s 712ms/step - loss: 0.5762 - accuracy: 0.7783 - val_loss: 1.1617 - val_accuracy: 0.6767
# Epoch 27/1000
# 46/46 [==============================] - 30s 643ms/step - loss: 0.5569 - accuracy: 0.7851 - val_loss: 1.1600 - val_accuracy: 0.6699
# Epoch 28/1000
# 46/46 [==============================] - 31s 677ms/step - loss: 0.5289 - accuracy: 0.7949 - val_loss: 1.1932 - val_accuracy: 0.6828
# Epoch 29/1000
# 46/46 [==============================] - 27s 581ms/step - loss: 0.5258 - accuracy: 0.7920 - val_loss: 1.2043 - val_accuracy: 0.6917
# Epoch 30/1000
# 46/46 [==============================] - 27s 577ms/step - loss: 0.5142 - accuracy: 0.7938 - val_loss: 1.1939 - val_accuracy: 0.6999
# Epoch 31/1000
# 46/46 [==============================] - 27s 580ms/step - loss: 0.5048 - accuracy: 0.8002 - val_loss: 1.1969 - val_accuracy: 0.6992
# Epoch 32/1000
# 46/46 [==============================] - 27s 591ms/step - loss: 0.4767 - accuracy: 0.8094 - val_loss: 1.2335 - val_accuracy: 0.6883

# %%
# load in model
model = keras.models.load_model("cnn.h5")

# %%
# final evaluation statisticson training and test data
model.evaluate(X_train,Y_train)
model.evaluate(X_test,Y_test)
# Out:
# 183/183 [==============================] - 8s 45ms/step - loss: 0.3131 - accuracy: 0.9398
# 46/46 [==============================] - 2s 52ms/step - loss: 1.0894 - accuracy: 0.6767
# [1.0893802642822266, 0.6766917109489441]

# %%
# test image to classify
plt.imshow(data1[1000].reshape(128,128))

# %%
types = np.unique(y)

# predict test image
types[np.argmax(model.predict(data1[1000].reshape(-1,128,128,1))[0])]
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 'intraparenchymal'

# %%
# test image true label
y[1000]
# Out:
# 'intraparenchymal'

# %%
# predictions on test data
y_pred = model.predict(X_test)
# Out:
# 46/46 [==============================] - 2s 38ms/step

# %%
# confusion matrix for CNN1
fig = ConfusionMatrixDisplay(confusion_matrix(Y_test.argmax(axis=1), y_pred.argmax(axis=1)), display_labels=types)
fig.plot(xticks_rotation='90')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Convolutional Neural Network 2
#
# Re-downscaled data in both x and y directions taking the average, same model as CNN1

# %%
# test new downscaling function
plt.imshow(block_reduce(data[0].reshape(512,512), (4,4), func=np.mean))

# %%
# re-downscale the dataset
DS = 16
im_size = int(262144/DS)

data2 = np.zeros([len(all_labels), im_size])

for i, row in enumerate(data):
    data2[i,:] = block_reduce(row.reshape(512,512), (4,4), func=np.mean).reshape(-1)

# %%
# split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data2, y, test_size=0.2, random_state=0)

# reshape as necessary
Y_train = pd.get_dummies(y_train).values
Y_test = pd.get_dummies(y_test).values
X_train = X_train.reshape(-1,128,128,1)
X_test = X_test.reshape(-1,128,128,1)

# %%
X_test.shape
# Out:
# (1463, 128, 128, 1)

# %%
import os

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#define model
model = Sequential()
model.add(Conv2D(32, (7,7),
                 padding='valid',
                 input_shape=(128,128,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, (3,3),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=6, activation='softmax'))

# compile model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
keras.utils.plot_model(model, "cnn_v2.png", show_shapes=True)

# early stopping
run_index = 2 # increment this at every run
run_logdir = os.path.join(os.curdir, "convolution_logs", "run_{:03d}".format(run_index))

early_stopping_cb = keras.callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=10, # how many epochs to wait before stopping
)
checkpoint_cb = keras.callbacks.ModelCheckpoint("cnn_v2.h5", save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

# fit and validate using new downscaled image data
history = model.fit(X_train,
                    Y_train,
                    epochs=1000,
                    batch_size=128,
                    verbose=1,
                    validation_data=(X_test, Y_test),
                    callbacks=[checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/1000
# 46/46 [==============================] - 32s 665ms/step - loss: 5.9991 - accuracy: 0.3316 - val_loss: 1.5318 - val_accuracy: 0.4019
# Epoch 2/1000
# 46/46 [==============================] - 30s 643ms/step - loss: 1.5291 - accuracy: 0.3901 - val_loss: 1.4700 - val_accuracy: 0.4334
# Epoch 3/1000
# 46/46 [==============================] - 30s 642ms/step - loss: 1.4356 - accuracy: 0.4325 - val_loss: 1.4498 - val_accuracy: 0.4682
# Epoch 4/1000
# 46/46 [==============================] - 34s 746ms/step - loss: 1.3410 - accuracy: 0.4788 - val_loss: 1.3428 - val_accuracy: 0.5038
# Epoch 5/1000
# 46/46 [==============================] - 33s 712ms/step - loss: 1.2413 - accuracy: 0.5224 - val_loss: 1.2878 - val_accuracy: 0.5420
# Epoch 6/1000
# 46/46 [==============================] - 30s 643ms/step - loss: 1.1375 - accuracy: 0.5607 - val_loss: 1.2244 - val_accuracy: 0.5653
# Epoch 7/1000
# 46/46 [==============================] - 30s 655ms/step - loss: 1.0397 - accuracy: 0.6085 - val_loss: 1.1930 - val_accuracy: 0.5851
# Epoch 8/1000
# 46/46 [==============================] - 30s 643ms/step - loss: 0.9511 - accuracy: 0.6374 - val_loss: 1.1208 - val_accuracy: 0.6165
# Epoch 9/1000
# 46/46 [==============================] - 30s 644ms/step - loss: 0.8542 - accuracy: 0.6805 - val_loss: 1.1149 - val_accuracy: 0.6439
# Epoch 10/1000
# 46/46 [==============================] - 30s 647ms/step - loss: 0.7724 - accuracy: 0.6985 - val_loss: 1.0643 - val_accuracy: 0.6644
# Epoch 11/1000
# 46/46 [==============================] - 30s 645ms/step - loss: 0.7336 - accuracy: 0.7191 - val_loss: 1.0598 - val_accuracy: 0.6692
# Epoch 12/1000
# 46/46 [==============================] - 31s 667ms/step - loss: 0.6685 - accuracy: 0.7460 - val_loss: 1.0379 - val_accuracy: 0.6787
# Epoch 13/1000
# 46/46 [==============================] - 30s 653ms/step - loss: 0.6338 - accuracy: 0.7544 - val_loss: 1.0777 - val_accuracy: 0.6760
# Epoch 14/1000
# 46/46 [==============================] - 30s 644ms/step - loss: 0.5890 - accuracy: 0.7803 - val_loss: 1.0586 - val_accuracy: 0.6897
# Epoch 15/1000
# 46/46 [==============================] - 30s 649ms/step - loss: 0.5391 - accuracy: 0.7913 - val_loss: 1.0522 - val_accuracy: 0.7006
# Epoch 16/1000
# 46/46 [==============================] - 30s 646ms/step - loss: 0.5070 - accuracy: 0.8079 - val_loss: 1.1274 - val_accuracy: 0.7027
# Epoch 17/1000
# 46/46 [==============================] - 30s 645ms/step - loss: 0.4812 - accuracy: 0.8164 - val_loss: 1.0830 - val_accuracy: 0.7075
# Epoch 18/1000
# 46/46 [==============================] - 30s 651ms/step - loss: 0.4565 - accuracy: 0.8212 - val_loss: 1.1693 - val_accuracy: 0.7027
# Epoch 19/1000
# 46/46 [==============================] - 30s 654ms/step - loss: 0.4431 - accuracy: 0.8323 - val_loss: 1.0770 - val_accuracy: 0.7061
# Epoch 20/1000
# 46/46 [==============================] - 30s 644ms/step - loss: 0.4254 - accuracy: 0.8301 - val_loss: 1.1633 - val_accuracy: 0.7054
# Epoch 21/1000
# 46/46 [==============================] - 30s 646ms/step - loss: 0.4031 - accuracy: 0.8475 - val_loss: 1.1402 - val_accuracy: 0.7198
# Epoch 22/1000
# 46/46 [==============================] - 30s 651ms/step - loss: 0.3902 - accuracy: 0.8515 - val_loss: 1.1184 - val_accuracy: 0.7150

# %%
# load in model
model = keras.models.load_model("cnn_v2.h5")

# %%
# final evaluation statisticson training and test data
model.evaluate(X_train,Y_train)
model.evaluate(X_test,Y_test)
# Out:
# 183/183 [==============================] - 7s 37ms/step - loss: 0.3382 - accuracy: 0.9272
# 46/46 [==============================] - 2s 37ms/step - loss: 1.0379 - accuracy: 0.6787
# [1.0379180908203125, 0.6787422895431519]

# %%
# test image to classify
plt.imshow(data2[14].reshape(128,128))

# %%
types = np.unique(y)

# predict test image
types[np.argmax(model.predict(data2[14].reshape(-1,128,128,1))[0])]
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 'epidural'

# %%
# test image true label
y[14]
# Out:
# 'epidural'

# %%
# predictions on test data
y_pred = model.predict(X_test)

# confusion matrix for CNN2
fig = ConfusionMatrixDisplay(confusion_matrix(Y_test.argmax(axis=1), y_pred.argmax(axis=1)), display_labels=types)
fig.plot(xticks_rotation='90')
plt.tight_layout()
plt.show()
# Out:
# 46/46 [==============================] - 2s 38ms/step

# %% [markdown]
# ## Convolutional Neural Network 3
#
# Run on same downscaled image data as CNN2, changes in convolutional layers

# %%
import os

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# define model
model = Sequential()
model.add(Conv2D(64, (7,7),
                 padding='valid',
                 input_shape=(128,128,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, (3,3),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=6, activation='softmax'))

# compile model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
keras.utils.plot_model(model, "cnn_v4.png", show_shapes=True)

# early stopping
run_index = 2 # increment this at every run
run_logdir = os.path.join(os.curdir, "convolution_logs", "run_{:03d}".format(run_index))

early_stopping_cb = keras.callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=10, # how many epochs to wait before stopping
)
checkpoint_cb = keras.callbacks.ModelCheckpoint("cnn_v4.h5", save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

# fit and validate using second downscaled image data
history = model.fit(X_train,
                    Y_train,
                    epochs=1000,
                    batch_size=128,
                    verbose=1,
                    validation_data=(X_test, Y_test),
                    callbacks=[checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/1000
# 46/46 [==============================] - 51s 1s/step - loss: 6.4631 - accuracy: 0.3496 - val_loss: 1.5575 - val_accuracy: 0.4026
# Epoch 2/1000
# 46/46 [==============================] - 50s 1s/step - loss: 1.5119 - accuracy: 0.4123 - val_loss: 1.4814 - val_accuracy: 0.4381
# Epoch 3/1000
# 46/46 [==============================] - 52s 1s/step - loss: 1.3835 - accuracy: 0.4711 - val_loss: 1.3854 - val_accuracy: 0.4826
# Epoch 4/1000
# 46/46 [==============================] - 50s 1s/step - loss: 1.2349 - accuracy: 0.5349 - val_loss: 1.2897 - val_accuracy: 0.5414
# Epoch 5/1000
# 46/46 [==============================] - 49s 1s/step - loss: 1.0925 - accuracy: 0.6009 - val_loss: 1.2342 - val_accuracy: 0.5619
# Epoch 6/1000
# 46/46 [==============================] - 49s 1s/step - loss: 0.9584 - accuracy: 0.6448 - val_loss: 1.1979 - val_accuracy: 0.5844
# Epoch 7/1000
# 46/46 [==============================] - 51s 1s/step - loss: 0.8641 - accuracy: 0.6844 - val_loss: 1.1441 - val_accuracy: 0.6220
# Epoch 8/1000
# 46/46 [==============================] - 50s 1s/step - loss: 0.7714 - accuracy: 0.7241 - val_loss: 1.1148 - val_accuracy: 0.6357
# Epoch 9/1000
# 46/46 [==============================] - 48s 1s/step - loss: 0.6860 - accuracy: 0.7564 - val_loss: 1.0958 - val_accuracy: 0.6576
# Epoch 10/1000
# 46/46 [==============================] - 50s 1s/step - loss: 0.6227 - accuracy: 0.7757 - val_loss: 1.0973 - val_accuracy: 0.6808
# Epoch 11/1000
# 46/46 [==============================] - 48s 1s/step - loss: 0.5583 - accuracy: 0.7998 - val_loss: 1.1198 - val_accuracy: 0.6815
# Epoch 12/1000
# 46/46 [==============================] - 48s 1s/step - loss: 0.5165 - accuracy: 0.8067 - val_loss: 1.1630 - val_accuracy: 0.6794
# Epoch 13/1000
# 46/46 [==============================] - 48s 1s/step - loss: 0.4779 - accuracy: 0.8274 - val_loss: 1.1542 - val_accuracy: 0.6986
# Epoch 14/1000
# 46/46 [==============================] - 48s 1s/step - loss: 0.4535 - accuracy: 0.8344 - val_loss: 1.1263 - val_accuracy: 0.7109
# Epoch 15/1000
# 46/46 [==============================] - 48s 1s/step - loss: 0.4011 - accuracy: 0.8552 - val_loss: 1.1787 - val_accuracy: 0.6999
# Epoch 16/1000
# 46/46 [==============================] - 48s 1s/step - loss: 0.3828 - accuracy: 0.8609 - val_loss: 1.1626 - val_accuracy: 0.6972
# Epoch 17/1000
# 46/46 [==============================] - 50s 1s/step - loss: 0.3636 - accuracy: 0.8672 - val_loss: 1.2456 - val_accuracy: 0.6979
# Epoch 18/1000
# 46/46 [==============================] - 48s 1s/step - loss: 0.3469 - accuracy: 0.8723 - val_loss: 1.2312 - val_accuracy: 0.7020
# Epoch 19/1000
# 46/46 [==============================] - 48s 1s/step - loss: 0.3347 - accuracy: 0.8745 - val_loss: 1.2597 - val_accuracy: 0.6999

# %%
# final evaluation statisticson training and test data
model.evaluate(X_train,Y_train)
model.evaluate(X_test,Y_test)
# Out:
# 183/183 [==============================] - 16s 86ms/step - loss: 0.0767 - accuracy: 0.9901
# 46/46 [==============================] - 4s 79ms/step - loss: 1.2597 - accuracy: 0.6999
# [1.259665608406067, 0.6999316215515137]

# %%
# save model
model.save("cnn_v5.h5")

# %%
# predictions on test data
y_pred = model.predict(X_test)

# confusion matrix for CNN3
fig = ConfusionMatrixDisplay(confusion_matrix(Y_test.argmax(axis=1), y_pred.argmax(axis=1)), display_labels=types)
fig.plot(xticks_rotation='90')
plt.tight_layout()
plt.show()
# Out:
# 46/46 [==============================] - 4s 87ms/step
